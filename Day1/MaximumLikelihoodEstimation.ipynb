# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize

# %%
# %matplotlib notebook

# %% [markdown]
# # Maximum Likelihood Estimation
#
# -----
# *Version 0.1*
#
#
# By AA Miller (Northwestern/CIERA)
#
# 18 May 2025

# %% [markdown]
# **Notebook summary and learning objectives**
#
# The lecture covered an introduction to frequentist statistics, in which it is assumed that model parameters are fixed constants that cannot change. The frequentist standard for estimating model parameters following the collection of observations is [maximum likelihood estimation](https://en.wikipedia.org/wiki/Maximum_likelihood_estimation).
#
# In this notebook you will learn to:
# $~~~~~~~~$(1) calculate the likelihood for a set of observations with Gaussian uncertainties
# $~~~~~~~~$(2) maximize the likelihood via numerical minimization of the negative log likelihood
# $~~~~~~~~$(3) perform a bootstrap analysis to estimate uncertainties on the model parameters
# $~~~~~~~~$(4) use different metrics to compare models and select the one that is "best"
# $~~~~~~~~$(5) understand the limitations of gradient descent

# %% [markdown]
# ## Problem 0) Helper Functions
#
# We will need to make lots of plots of data and models throughout this notebook.

# %% [markdown]
# **Problem 0a**
#
# Write a function `data_plot()` that creates and returns `matplotlib` figure and axes instances using [`plt.subplots`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html).
#
# The function should label the abcissa `x` and the ordinate `y`, and take optional arguments `x_obs`, `y_obs`, `y_obs_unc` that are plotted when provided by the user.

# %%
def data_plot(x_obs=[], y_obs=[], y_obs_unc=[]):
    
    fig, ax = plt.subplots()
    
    if len(x_obs) > 0 and len(y_obs) > 0:
        if len(y_obs_unc) > 0:
            ax.errorbar(x_obs, y_obs, y_obs_unc, 
                        fmt='o', mec='RebeccaPurple', mfc='white', 
                        ecolor='RebeccaPurple')
        else:
            ax.errorbar(x_obs, y_obs, 
                        fmt='o', mec='RebeccaPurple', mfc='white')
    
    ax.set_xlabel('x')# complete
    ax.set_ylabel('y') # complete

    return fig, ax

# %% [markdown]
# **Problem 0b**
#
# Using `np.random` simulate 15 observations that are drawn from a linear relation defined by $f(x) = 3.14\,x + 6.626$. The observations should be collected over the range [0,10].
#
# Assume that the observations are noisy, and the scatter is described by a Gaussian with variance = 9.

# %%
n_obs = 15 # complete
rng = np.random.default_rng(seed=2009)

x_obs = rng.uniform(0, 10, n_obs)
y_obs = rng.normal(3.14*x_obs + 6.626, 3)
y_obs_unc = np.ones_like(y_obs)*3

# %% [markdown]
# **Problem 0c**
#
# Confirm your results from the previous two problems by using `data_plot()` to display the observations generated in **0b**.

# %%
fig, ax = data_plot(x_obs, y_obs, y_obs_unc)# complete
ax.set_title(r"Observational Data for $f(x) = 3.14x + 6.626$ with Fixed Undertainty")
fig.tight_layout()
plt.show()

# %% [markdown]
# **Problem 0d**
#
# Confirm you can add to your figure instance by over-plotting the true relation used to generate the data.
#
# Did you get the Gaussian scatter correct?
#
# *Hint* – for Gaussian noise $\sim$ 68\% of the observations should be within 1-$\sigma$ of the true relation.

# %%
fig, ax = data_plot(x_obs, y_obs, y_obs_unc)# complete
ax.set_title(r"Observational Data for $f(x) = 3.14x + 6.626$ with Fixed Undertainty")
plt.plot([0,10], [6.626, 6.626 + 31.4], '0.2')
fig.tight_layout()
plt.show()

# %% [markdown]
# *write your answer here*

# %% [markdown]
# ## Problem 1) The likelihood
#
# As we saw in Lecture II, the likelihood is just the product of the probability of all the individual observations within a data set:
#
# $$\mathcal{L} \equiv \prod p(x_i|\mathcal{M}(\theta))$$

# %% [markdown]
# Our aim is to identify model parameters $\theta$ that *maximize* the likelihood.

# %% [markdown]
# **Probelm 1a**
#
# Write a function `model` with two input parameters, `theta` and `x`, where `theta` is a tuple with values $\theta_0$ and $\theta_1$, and the function returns $\theta_0 + \theta_1 x$.
#
# *Hint* – this is far more formal than necessary, but it will simplify other problems later in the notebook.

# %%
def model(theta, x):
    '''
    Return dependent variable values for f(x) = theta_0 + theta_1 x
    
    Parameters
    ----------
    theta : tuple (size=2)
        theta[0] is the intercept and theta[1] is the slope of the line
    
    x : array-like
        values of the independent variable where f(x) should be evaluated
    '''
    theta0, theta1 = theta # complete
    
    return theta0 + theta1*x # complete

# %% [markdown]
# **Problem 1b**
#
# Write a function `prob` that calculates and returns the probability of observations `x` assuming that $p(x)$ follows a normal distribution with mean `mu` and standard deviation `sigma`.

# %%
def prob(x, mu, sigma):
    coef = 1/(sigma * np.sqrt(2*np.pi))
    exponent = - (x - mu)**2 / (2 * sigma**2)
    p = coef * np.exp(exponent) # complete
    return p

# %% [markdown]
# **Problem 1c**
#
# Calculate the likelihood for the observations that were simulated in **0b**. Use the model parameters that generated the data.
#
# *Hint* – think carefully about your variable names.

# %%
lkhd = np.prod(prob(y_obs, model((6.626, 3.14), x_obs), y_obs_unc))

print(f'The likelihood for this data set is {lkhd}')
# Out:
# The likelihood for this data set is 2.03322667294441e-18

# %% [markdown]
# That is a very small number!

# %% [markdown]
# **Problem 1d**
#
# Using the same model parameters as before, generate data sets of 100, 200, and 300 observations, and calculate the likelihood for each.
#
# *Hint* – do not use the same variable names (e.g., `x_obs`, `y_obs`, etc) that we used before; we do not want to over-write those variables.

# %%
for n_obs in np.arange(300): # complete

    rng = np.random.default_rng(seed=2009)

        # x_obs = rng.uniform(0, 10, n_obs)
        # y_obs = rng.normal(3.14*x_obs + 6.626, 3)
        # y_obs_unc = np.ones_like(y_obs)*3
    
    x_sim = rng.uniform(0, 10, n_obs) # complete
    y_sim = rng.normal(3.14*x_sim + 6.626, 2.5) # complete
    y_sim_unc = np.ones_like(y_sim)*3 # complete

    lkhd = np.prod(prob(y_sim, model((6.626, 3.14), x_sim), y_sim_unc))# complete

    print(f'The likelihood for {n_obs} observations is {lkhd}')
# Out:
# The likelihood for 0 observations is 1.0
# The likelihood for 1 observations is 0.043433460509762066
# The likelihood for 2 observations is 0.009536838864696444
# The likelihood for 3 observations is 0.0010799051072767332
# The likelihood for 4 observations is 0.00014978722737371265
# The likelihood for 5 observations is 7.122501010608124e-06
# The likelihood for 6 observations is 8.12176366687797e-07
# The likelihood for 7 observations is 6.028615189042547e-08
# The likelihood for 8 observations is 4.062290393486808e-09
# The likelihood for 9 observations is 2.1088855073339193e-09
# The likelihood for 10 observations is 9.032247948963579e-11
# The likelihood for 11 observations is 1.1752725507350543e-11
# The likelihood for 12 observations is 1.4393862330628094e-12
# The likelihood for 13 observations is 1.8454813016128634e-13
# The likelihood for 14 observations is 5.128182678728556e-15
# The likelihood for 15 observations is 4.989418883844267e-17
# The likelihood for 16 observations is 1.2180017675349684e-17
# The likelihood for 17 observations is 1.3858606333294693e-18
# The likelihood for 18 observations is 7.15538083942677e-20
# The likelihood for 19 observations is 3.52452351913862e-21
# The likelihood for 20 observations is 7.818886499269813e-23
# The likelihood for 21 observations is 2.826655449627781e-23
# The likelihood for 22 observations is 1.2416544561386819e-24
# The likelihood for 23 observations is 1.316676686146274e-25
# The likelihood for 24 observations is 1.080989681567164e-26
# The likelihood for 25 observations is 4.888790008538013e-28
# The likelihood for 26 observations is 7.001699903234753e-29
# The likelihood for 27 observations is 3.760657313679028e-30
# The likelihood for 28 observations is 1.221798550009678e-30
# The likelihood for 29 observations is 6.163913725400657e-33
# The likelihood for 30 observations is 3.670319620321582e-33
# The likelihood for 31 observations is 2.3522985969178833e-33
# The likelihood for 32 observations is 1.7936417952815438e-35
# The likelihood for 33 observations is 2.4281094842464877e-36
# The likelihood for 34 observations is 4.3758036322636155e-38
# The likelihood for 35 observations is 3.245501638817514e-39
# The likelihood for 36 observations is 2.804874381312571e-40
# The likelihood for 37 observations is 8.729900879412376e-41
# The likelihood for 38 observations is 1.1036755308331227e-41
# The likelihood for 39 observations is 5.856484761300369e-43
# The likelihood for 40 observations is 5.077908780209953e-44
# The likelihood for 41 observations is 2.4375918290074e-45
# The likelihood for 42 observations is 1.644430077164848e-45
# The likelihood for 43 observations is 2.8681701614251847e-46
# The likelihood for 44 observations is 2.1434320682768488e-47
# The likelihood for 45 observations is 1.5140745301080644e-48
# The likelihood for 46 observations is 1.336272618556203e-49
# The likelihood for 47 observations is 3.396869288321391e-50
# The likelihood for 48 observations is 1.8278797145789568e-51
# The likelihood for 49 observations is 5.730786401684222e-52
# The likelihood for 50 observations is 6.748345702709026e-53
# The likelihood for 51 observations is 6.169025863947471e-54
# The likelihood for 52 observations is 4.205727011565355e-55
# The likelihood for 53 observations is 7.207442732560201e-56
# The likelihood for 54 observations is 1.2054954053205929e-57
# The likelihood for 55 observations is 1.319837700104505e-59
# The likelihood for 56 observations is 9.535803806214932e-61
# The likelihood for 57 observations is 6.830061751210965e-62
# The likelihood for 58 observations is 5.021419210781776e-63
# The likelihood for 59 observations is 7.061218150322622e-64
# The likelihood for 60 observations is 3.1342125135079344e-64
# The likelihood for 61 observations is 3.629291033951408e-65
# The likelihood for 62 observations is 4.5473799439746214e-66
# The likelihood for 63 observations is 4.301312623925787e-67
# The likelihood for 64 observations is 6.24653852184049e-68
# The likelihood for 65 observations is 1.7233918146771665e-69
# The likelihood for 66 observations is 4.054333819803024e-70
# The likelihood for 67 observations is 2.2231724287104176e-70
# The likelihood for 68 observations is 1.1062903576249051e-71
# The likelihood for 69 observations is 4.0555032257521304e-73
# The likelihood for 70 observations is 5.787351305696191e-74
# The likelihood for 71 observations is 6.501421096996347e-75
# The likelihood for 72 observations is 9.455553735366026e-76
# The likelihood for 73 observations is 5.8114236320285425e-77
# The likelihood for 74 observations is 3.038160134514208e-78
# The likelihood for 75 observations is 5.424827483080214e-79
# The likelihood for 76 observations is 5.685332743732228e-80
# The likelihood for 77 observations is 3.1306572495577985e-81
# The likelihood for 78 observations is 8.913920109852358e-83
# The likelihood for 79 observations is 1.6099388587975113e-83
# The likelihood for 80 observations is 3.6300337823864587e-84
# The likelihood for 81 observations is 3.7013494070240484e-85
# The likelihood for 82 observations is 1.6349604722656444e-86
# The likelihood for 83 observations is 5.9430078230482785e-87
# The likelihood for 84 observations is 6.435654964553112e-88
# The likelihood for 85 observations is 7.501417186182234e-89
# The likelihood for 86 observations is 2.1226472530237314e-90
# The likelihood for 87 observations is 1.1376957943245318e-91
# The likelihood for 88 observations is 3.821523328251558e-93
# The likelihood for 89 observations is 4.964882272257136e-94
# The likelihood for 90 observations is 2.3061054603948025e-95
# The likelihood for 91 observations is 6.725791394902032e-97
# The likelihood for 92 observations is 4.0272860472877993e-98
# The likelihood for 93 observations is 3.951523333307168e-99
# The likelihood for 94 observations is 3.825400088818993e-100
# The likelihood for 95 observations is 3.341330110896019e-101
# The likelihood for 96 observations is 4.1131845760496244e-102
# The likelihood for 97 observations is 3.799211024805208e-103
# The likelihood for 98 observations is 4.063921700849922e-104
# The likelihood for 99 observations is 5.007071281555393e-105
# The likelihood for 100 observations is 4.770100734617574e-106
# The likelihood for 101 observations is 9.934997366708847e-107
# The likelihood for 102 observations is 1.2626103252124237e-107
# The likelihood for 103 observations is 2.1372642824015544e-108
# The likelihood for 104 observations is 9.085653041968139e-111
# The likelihood for 105 observations is 9.378136929556268e-112
# The likelihood for 106 observations is 1.1660110593667372e-112
# The likelihood for 107 observations is 7.362638231918777e-114
# The likelihood for 108 observations is 4.6755547790275575e-114
# The likelihood for 109 observations is 8.454514691189783e-115
# The likelihood for 110 observations is 9.046794350936025e-115
# The likelihood for 111 observations is 1.3512416941779344e-115
# The likelihood for 112 observations is 1.548514484417658e-116
# The likelihood for 113 observations is 1.013245613567938e-117
# The likelihood for 114 observations is 5.12095346907592e-119
# The likelihood for 115 observations is 6.365094129047518e-120
# The likelihood for 116 observations is 1.911206192288137e-121
# The likelihood for 117 observations is 2.0753908040873623e-122
# The likelihood for 118 observations is 1.872350407959688e-123
# The likelihood for 119 observations is 1.190285497405133e-123
# The likelihood for 120 observations is 1.5797461008217958e-124
# The likelihood for 121 observations is 2.0222730656537487e-125
# The likelihood for 122 observations is 2.6420378936227668e-126
# The likelihood for 123 observations is 2.2483680419666954e-127
# The likelihood for 124 observations is 2.583893055861422e-128
# The likelihood for 125 observations is 3.355886302608365e-129
# The likelihood for 126 observations is 6.2634931499012924e-130
# The likelihood for 127 observations is 1.1039036940551853e-131
# The likelihood for 128 observations is 1.4381385793682168e-132
# The likelihood for 129 observations is 4.5411116874824655e-134
# The likelihood for 130 observations is 1.0083747815593176e-134
# The likelihood for 131 observations is 8.094796436968658e-136
# The likelihood for 132 observations is 1.4394798659645137e-136
# The likelihood for 133 observations is 9.58358638821463e-138
# The likelihood for 134 observations is 6.014743969446206e-139
# The likelihood for 135 observations is 3.1728171167920477e-140
# The likelihood for 136 observations is 3.4752747228922053e-141
# The likelihood for 137 observations is 4.950567815006687e-142
# The likelihood for 138 observations is 3.2857229327962195e-143
# The likelihood for 139 observations is 2.77737567742737e-143
# The likelihood for 140 observations is 2.417562330168558e-145
# The likelihood for 141 observations is 4.276841306780474e-146
# The likelihood for 142 observations is 6.797553554791432e-147
# The likelihood for 143 observations is 4.24311068680564e-148
# The likelihood for 144 observations is 5.843246561703784e-149
# The likelihood for 145 observations is 3.515231825058598e-150
# The likelihood for 146 observations is 5.6103861136326956e-151
# The likelihood for 147 observations is 7.27611241805339e-152
# The likelihood for 148 observations is 1.2461234206964852e-152
# The likelihood for 149 observations is 1.4472164439167253e-153
# The likelihood for 150 observations is 1.1362972555259164e-155
# The likelihood for 151 observations is 1.340414806540875e-156
# The likelihood for 152 observations is 1.8462012818860768e-158
# The likelihood for 153 observations is 9.564165285234256e-160
# The likelihood for 154 observations is 8.179021425879136e-161
# The likelihood for 155 observations is 7.706122089396338e-162
# The likelihood for 156 observations is 4.882813135449837e-162
# The likelihood for 157 observations is 6.409321338053988e-163
# The likelihood for 158 observations is 8.809177381292832e-164
# The likelihood for 159 observations is 4.34049637427147e-165
# The likelihood for 160 observations is 5.1700643926973935e-166
# The likelihood for 161 observations is 2.6640102478638826e-167
# The likelihood for 162 observations is 7.123742224732551e-168
# The likelihood for 163 observations is 5.048239537850724e-169
# The likelihood for 164 observations is 1.440204682959456e-169
# The likelihood for 165 observations is 1.9441342493395868e-170
# The likelihood for 166 observations is 8.996993797565848e-172
# The likelihood for 167 observations is 1.0676440957272532e-172
# The likelihood for 168 observations is 6.508119375648868e-175
# The likelihood for 169 observations is 9.77191176205334e-176
# The likelihood for 170 observations is 4.093279487143434e-177
# The likelihood for 171 observations is 4.7422800643483824e-178
# The likelihood for 172 observations is 2.5804843779943333e-178
# The likelihood for 173 observations is 3.418074807345625e-179
# The likelihood for 174 observations is 4.567104281186485e-180
# The likelihood for 175 observations is 6.458205541216421e-181
# The likelihood for 176 observations is 2.825623316617327e-181
# The likelihood for 177 observations is 3.801326580213342e-182
# The likelihood for 178 observations is 3.860206955422289e-183
# The likelihood for 179 observations is 3.798291010223312e-184
# The likelihood for 180 observations is 7.292697040140257e-186
# The likelihood for 181 observations is 2.8524230692671227e-186
# The likelihood for 182 observations is 1.0707959221160998e-187
# The likelihood for 183 observations is 6.326422244060913e-188
# The likelihood for 184 observations is 2.315196599511972e-188
# The likelihood for 185 observations is 2.1502799506208635e-189
# The likelihood for 186 observations is 7.582974838384802e-191
# The likelihood for 187 observations is 9.458493791204542e-192
# The likelihood for 188 observations is 3.2203210242550085e-193
# The likelihood for 189 observations is 2.3315577594699506e-194
# The likelihood for 190 observations is 3.422786533902655e-195
# The likelihood for 191 observations is 3.907823548256097e-196
# The likelihood for 192 observations is 3.722406226056871e-197
# The likelihood for 193 observations is 4.125178614476831e-198
# The likelihood for 194 observations is 6.459062019715e-199
# The likelihood for 195 observations is 5.805673531983465e-200
# The likelihood for 196 observations is 4.130976479486273e-201
# The likelihood for 197 observations is 3.443728427086199e-202
# The likelihood for 198 observations is 1.9079734777060517e-203
# The likelihood for 199 observations is 2.4232157764348105e-204
# The likelihood for 200 observations is 3.626023373698826e-205
# The likelihood for 201 observations is 4.562841828614819e-206
# The likelihood for 202 observations is 6.449069083581485e-207
# The likelihood for 203 observations is 2.3713367287083617e-208
# The likelihood for 204 observations is 6.586857393418428e-209
# The likelihood for 205 observations is 3.6725112072924065e-210
# The likelihood for 206 observations is 3.811517746754994e-211
# The likelihood for 207 observations is 1.8776144649202398e-212
# The likelihood for 208 observations is 2.143501027785035e-213
# The likelihood for 209 observations is 1.4975058962104835e-214
# The likelihood for 210 observations is 1.7688173671661375e-215
# The likelihood for 211 observations is 5.2817718845873005e-216
# The likelihood for 212 observations is 6.858049043058564e-217
# The likelihood for 213 observations is 1.832865500742158e-216
# The likelihood for 214 observations is 2.0140839428838803e-217
# The likelihood for 215 observations is 9.058353828535164e-219
# The likelihood for 216 observations is 3.36195680599018e-220
# The likelihood for 217 observations is 4.291462260903142e-221
# The likelihood for 218 observations is 5.2575039746603383e-222
# The likelihood for 219 observations is 2.084098025224365e-222
# The likelihood for 220 observations is 3.457377175944638e-223
# The likelihood for 221 observations is 1.655888541914064e-224
# The likelihood for 222 observations is 9.069859849020442e-226
# The likelihood for 223 observations is 9.079400718292374e-227
# The likelihood for 224 observations is 1.5171490313085787e-228
# The likelihood for 225 observations is 1.756498955555217e-230
# The likelihood for 226 observations is 2.655834097656275e-231
# The likelihood for 227 observations is 3.1280275236908785e-232
# The likelihood for 228 observations is 4.105410199714433e-233
# The likelihood for 229 observations is 4.649579784419308e-234
# The likelihood for 230 observations is 5.3072779836745e-235
# The likelihood for 231 observations is 1.8649190912116352e-236
# The likelihood for 232 observations is 4.65947901050999e-237
# The likelihood for 233 observations is 1.930719471899127e-238
# The likelihood for 234 observations is 9.718939737796104e-240
# The likelihood for 235 observations is 8.012829096699002e-241
# The likelihood for 236 observations is 8.695764657729165e-242
# The likelihood for 237 observations is 5.209478504526964e-242
# The likelihood for 238 observations is 3.056316567630121e-244
# The likelihood for 239 observations is 2.8239009667723798e-244
# The likelihood for 240 observations is 2.976015849783237e-245
# The likelihood for 241 observations is 3.1381044633253623e-246
# The likelihood for 242 observations is 2.2538455122295307e-247
# The likelihood for 243 observations is 1.8630272091335234e-248
# The likelihood for 244 observations is 3.7679945500010664e-249
# The likelihood for 245 observations is 3.800517778431367e-251
# The likelihood for 246 observations is 2.6222049559026285e-252
# The likelihood for 247 observations is 1.844638527404438e-253
# The likelihood for 248 observations is 4.1721722775312815e-255
# The likelihood for 249 observations is 4.311025356238407e-257
# The likelihood for 250 observations is 1.3381953436114801e-258
# The likelihood for 251 observations is 1.777266679255309e-259
# The likelihood for 252 observations is 3.22285050635084e-260
# The likelihood for 253 observations is 2.165033827128092e-261
# The likelihood for 254 observations is 1.7936563665095314e-262
# The likelihood for 255 observations is 1.6829484304973266e-263
# The likelihood for 256 observations is 2.2012038182502093e-264
# The likelihood for 257 observations is 2.3661060761059015e-265
# The likelihood for 258 observations is 2.062950596516689e-266
# The likelihood for 259 observations is 8.800591950615753e-268
# The likelihood for 260 observations is 2.4128093649194613e-269
# The likelihood for 261 observations is 1.1549849740856859e-269
# The likelihood for 262 observations is 6.521663000662485e-271
# The likelihood for 263 observations is 3.806973520961768e-272
# The likelihood for 264 observations is 9.862628107813696e-273
# The likelihood for 265 observations is 4.383893030801688e-274
# The likelihood for 266 observations is 4.911838726511721e-276
# The likelihood for 267 observations is 1.0595890589291183e-276
# The likelihood for 268 observations is 7.901669612621375e-278
# The likelihood for 269 observations is 1.9736769655725555e-278
# The likelihood for 270 observations is 1.588162445127832e-279
# The likelihood for 271 observations is 1.1581730333926989e-280
# The likelihood for 272 observations is 2.408734979977897e-281
# The likelihood for 273 observations is 1.458057544708155e-282
# The likelihood for 274 observations is 1.449972397356193e-283
# The likelihood for 275 observations is 1.2689150056796375e-284
# The likelihood for 276 observations is 9.439153149577176e-286
# The likelihood for 277 observations is 1.5740511206330312e-286
# The likelihood for 278 observations is 1.3602033449954956e-287
# The likelihood for 279 observations is 1.0386879572571535e-288
# The likelihood for 280 observations is 2.7701961266385694e-289
# The likelihood for 281 observations is 3.020172119077754e-290
# The likelihood for 282 observations is 5.537199345291116e-291
# The likelihood for 283 observations is 6.700725814280924e-292
# The likelihood for 284 observations is 1.4848963181717747e-293
# The likelihood for 285 observations is 6.982198187832072e-295
# The likelihood for 286 observations is 2.725481074298549e-296
# The likelihood for 287 observations is 2.6376597564122695e-296
# The likelihood for 288 observations is 5.2654122502788954e-297
# The likelihood for 289 observations is 7.231154779596905e-298
# The likelihood for 290 observations is 5.598463264786674e-299
# The likelihood for 291 observations is 6.373730227226807e-300
# The likelihood for 292 observations is 1.4243100895261152e-300
# The likelihood for 293 observations is 1.9147433436290366e-301
# The likelihood for 294 observations is 9.141719136231029e-303
# The likelihood for 295 observations is 1.624968145595932e-303
# The likelihood for 296 observations is 2.2852318145426484e-304
# The likelihood for 297 observations is 2.2506139342467097e-305
# The likelihood for 298 observations is 2.2532097217242595e-306
# The likelihood for 299 observations is 2.4143613529401426e-307

# %% [markdown]
# 300 observations is a small number! Gaia has observed more than 1 billion stars, and yet, with only 300 observations in an outrageously simple dataset, the likelihood is so small it is equivalent to 0 at machine precision.
#
#
# This is why it is always a good idea to work with the log of the likelihood, not only does this turn a product into a sum, more importantly, the calculations become far more stable on your machine.

# %% [markdown]
# **Problem 1e**
#
# Write a function `lnl` that calculates the log likelihood for some observations, their uncertainties, and the model to which the observations are being compared. Assume that the likelihood is Gaussian.
#
# *Hint* – the `model` function that was created earlier should be inside the `lnl` function, this means that `theta` should be the first arguement for the `lnl` function.
#
# *Note* – likelihoods are calculated for comparison purposes, their absolute value does not have much meaning, so you can ignore constant terms for this function.

# %%
def lnl(theta, y_obs, y_obs_unc, x_obs):
    theta0, theta1 = theta
    lkhd = np.prod(prob(y_obs, model((theta0, theta1), x_obs), y_obs_unc)) # complete
    return np.log(lkhd) # complete

# %% [markdown]
# **Problem 1f**
#
# Using the same model parameters as before, generate data sets of 100, 200, and 300 observations, and calculate the *log likelihood* for each.

# %%
for n_obs in [100, 200, 300]:

    rng = np.random.default_rng(seed=2009)

    x_sim = rng.uniform(0, 10, n_obs)
    y_sim = rng.normal(3.14*x_sim + 6.626, 3)
    y_sim_unc = np.ones_like(x_sim)*3

    lnlike = lnl(theta=(6.626, 3.14), y_obs=y_sim, y_obs_unc=y_sim_unc, x_obs=x_sim)# complete

    print(f'The ln likelihood for {n_obs} observations is {lnlike}')
# Out:
# The ln likelihood for 100 observations is -260.4445433430229
# The ln likelihood for 200 observations is -500.32373048286865
# The ln likelihood for 300 observations is -inf
# /var/folders/q_/4fb27_xd0c72q79_qtw8qtjh0000gn/T/ipykernel_48115/1777849233.py:4: RuntimeWarning: divide by zero encountered in log
#   return np.log(lkhd) # complete

# %% [markdown]
# ## Problem 2) Maximizing the Likelihood
#
# It is all well and good to calculate the likelihood, but what we truly want is to maximize the likelihood.

# %% [markdown]
# Most algorithms are designed to minimize, rather than optimize, a function. Fortunately, minimizing the negative log likelihood is the exact same as maximizing the log likelihood.
#
# **Problem 2a**
#
# Write a function `nll` to calculate the negative log likelihood.
#
# *Hint* – this is really simple, don't overthink it.

# %%
def nll(theta, y_obs, y_obs_unc, x_obs):
    return # complete

# %% [markdown]
# **Problem 2b**
#
# Using [`minimize`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.minimize.html) from `scipy.optimize` determine the maximum likelihood estimation for the intercept and slope of the line that was used to generate the synthetic observations.
#
# *Hint* – for arguments `minimize` needs (1) a function, (2) an initial guess for the model parameters, which is why we've been using a tuple `theta`, and (3) a tuple containing the remaining arguments for the function to be minimized (i.e., the data/observations).

# %%
res = # complete

print(f'b = {res.x[0]:.4f} and m = {res.x[1]:.4f} for the MLE')

# %% [markdown]
# **Problem 2c**
#
# Overplot the line determined by the MLE on top of the synthetic data.
#
# How does the line compare to the true line used to generate the data?

# %%
fig, ax = data_plot(x_obs, y_obs, y_obs_unc)
ax.plot( # complete
ax.plot( # complete
ax.legend()
fig.tight_layout()

# %% [markdown]
# ## Problem 3) Point estimates are nice, but...
#
# In lecture we did not cover how to estimate uncertainties on the model parameters. When using [`curve_fit`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.curve_fit.html) in `scipy` analytic approximations to the shape of the likelihood are used to determine uncertainties on the model parameters.

# %% [markdown]
# These methods require that the data do not violate any of the underlying assumptions about the nature of the likelihood for a given problem. For this reason, I prefer to use the bootstrap method to estimate uncertainties on the MLE model parameters.
#
# Briefly, "new" data sets can be simulated via a bootstrap (randomly choosing a new data set from the observations with replacement) and then finding the MLE parameters again. This can be repeated many times to place confidence limits on the MLE estimates.

# %% [markdown]
# **Problem 3a**
#
# Using [np.random.choice](https://numpy.org/doc/stable/reference/random/generated/numpy.random.choice.html) select a bootstrap sample from the observations and estimate the MLE model parameters.
#
# *Hint* – choose a random index so that the input x, y, and y_unc samples are all the same.

# %%
boot_idx = np.random.choice( # complete

res = minimize(nll, (0,0), # complete

print(f'theta0 = {res.x[0]:.4f} and theta1 = {res.x[1]:.4f} for the MLE')

# %% [markdown]
# **Problem 3b**
#
# Create 100 bootstrap samples of the simulated observations and measure the MLE intercept and slope for each.
#
# Store the results in arrays called `theta0_boot` and `theta1_boot`.

# %%
n_boot = 100
theta0_boot = np.zeros(n_boot)
theta1_boot = np.zeros_like(theta0_boot)

for idx in range(n_boot):
    boot_idx = # complete
    res = # complete
    theta0_boot[idx] = # complete
    theta1_boot[idx] = # complete

# %% [markdown]
# **Problem 3c**
#
# The 68% confidence interval on $\theta_0$ (or $\theta_1$) is just the central 68% of the bootstrap distribution for the parameter.
#
# Use `np.percentile()` to determine the 68% C.I. on $\theta_0$ and $\theta_1$. Do these estimates bracket the true values used to generate the data?

# %%
print('The 68% C.I. on b is {:.4f} to {:.4f}'.format(*np.percentile(theta1_boot, # complete

print('The 68% C.I. on m is {:.4f} to {:.4f}'.format(*np.percentile(theta0_boot, # complete

# %% [markdown]
# *write your answer here*

# %% [markdown]
# **Problem 3d**
#
# What about correlations between the model parameters?
#
# Plot the 2d histogram of `theta0_boot` and `theta1_boot` to see if the estimates are correlated.

# %%
fig, ax = plt.subplots()

cax = ax.hist2d( # complete
fig.colorbar(cax[3])
fig.tight_layout()

# %% [markdown]
# ## Problem 4) Model Selection
#
# During lecture we saw two potential methods for selecting between different models. The first was using the $\chi^2_\mathrm{dof}$ and the second was AIC. We will briefly examine each below.

# %% [markdown]
# **Problem 4a**
#
# Plot the simulated data in the cell below.

# %%
n_obs = 23
rng = np.random.default_rng(seed=1851)
x_obs = rng.uniform(0, 10, n_obs)
y_obs = rng.normal(7.89*np.sin(2*np.pi*x_obs/23) + 0.4*x_obs, 1)
y_obs_unc = np.ones_like(y_obs)*1

fig, ax = data_plot(x_obs, y_obs, y_obs_unc)
fig.tight_layout()

# %% [markdown]
# **Problem 4b**
#
# Modify the function `model` from **1a** to accept a tuple of any length and return a polynomial of degree `len(theta)`-1. (This will allow us to compare polynomials of different degree in these problems)

# %%
def model(theta, x):
    '''
    Return dependent variable values for polynomial
    
    Parameters
    ----------
    theta : tuple
        coefficients for a polynomial of degree len(theta)-1
    
    x : array-like
        values of the independent variable where f(x) should be evaluated
    '''
    
    f_x = 0
    for c_num, coeff in enumerate(theta):
        f_x += coeff*x**c_num
    
    return # complete

# %% [markdown]
# **Problem 4c**
#
# Write a function `chi2dof` to calculate the $\chi^2_\mathrm{dof}$ for a polynomial model. The inputs should be `theta`, as well as the observations and their uncertainties.
#
# *Hint* – the solution will be dependent upon functions created in the previous problems.

# %%
def chi2dof(theta, y_obs, y_obs_unc, x_obs): 
    
    res = # complete

    dof = # complete
    
    chi2 = # complete
    
    return chi2/dof

# %% [markdown]
# **Problem 4d**
#
# Fit a first, second, and fifth order polynomial to the observations.
#
# Which model is "best" based on the $\chi^2_\mathrm{dof}$?
#
# Bonus points - overplot the MLE models on top of the data (you may need to modify `chi2dof` in order to do this easily).

# %%
for order in [1, 2, 5]:
    # complete
    print('The chi2 for {}th degree polynomial is: {}'.format( # complete

# %% [markdown]
# *write your response here*

# %% [markdown]
# ## Problem 5) Numerical stability
#
# Polynomials are often used for examples on numerical methods, but nature often provides more complex relations (exponentials, periodicity, power-laws, etc) between the quantities that we can measure. We will examine how that affects MLE.

# %% [markdown]
# **Problem 5a**
#
# Execute the cell below to simulate an exponentially declining signal that has a small "bump" at $x = 5$:
#
# $$f(x) = A \exp(-x) - B\;(x - C)^2 \exp(-(x - C)^2)$$
#
# where for this problem $A = 8$, $B = 15$ and $C = 5$.
#
# *Note* – there is no specific physical system that inspires this data, but you can find examples that look somewhat like this (e.g., an emission line in astronomical spectra or a resonance line in high-energy particle detectors).

# %%
n_obs = 55
rng = np.random.default_rng(seed=1851)
x_obs = rng.uniform(0, 10, n_obs)
y_obs = rng.normal(8*np.exp(-x_obs) - 15*(x_obs-5)**2*np.exp(-(x_obs-5)**2), 1)
y_obs_unc = np.ones_like(y_obs)*1

fig, ax = data_plot(x_obs, y_obs, y_obs_unc)
# ax.set_yscale('log')
fig.tight_layout()

# %% [markdown]
# **Problem 5b**
#
# Modify the function `model` to fit the declining exponential function $f(x)$ given in **5a**.

# %%
def model(theta, x):
    '''
    Return dependent variable values for polynomial
    
    Parameters
    ----------
    theta : tuple (size = 3)
        A, B, C values for the exponential function A np.exp(-x) - B*(x - C)**2 * np.exp(-(x - C)**2)
    
    x : array-like
        values of the independent variable where f(x) should be evaluated
    '''
    
    # complete
        
    
    return # complete

# %% [markdown]
# **Problem 5c**
#
# Find the maximum likelihood solution given the observations `y_obs` and `y_obs_unc`. Use an intial guess in your call to `nll` of (1, 1, 1).
#
# Are your results close to the correct answer?

# %%
res = # complete

print('A = {:.4f}, B = {:.4f}, C = {:.4f}'.format(*res.x))

# %% [markdown]
# *write your answer here*

# %% [markdown]
# **Problem 5d**
#
# Find the maximum likelihood solution given the observations `y_obs` and `y_obs_unc`. Use an intial guess in your call to `nll` of (20, 20, 20).
#
# Are your results close to the correct answer?

# %%
res = # complete

print('A = {:.4f}, B = {:.4f}, C = {:.4f}'.format(*res.x))

# %% [markdown]
# *write your answer here*

# %% [markdown]
# Here we have identified one of the problems with MLE (though to be fair, there are similar issues if you are conducting a Bayesian analysis): there is no guarantee that the minimization algorithm that is being used will identify a global minimum. The results that the algorithm obtains can be highly dependent upon the starting position for the minimizer or even the method used to perform the minimization.

# %% [markdown]
# **Problem 5e**
#
# Consult the docs for `minimize` and adjust parameters relative to the defaults, but the same starting point as **5d** (20,20,20), to arrive at a better solution for the values of $A$, $B$, and $C$.

# %%
res = # complete

print('A = {:.4f}, B = {:.4f}, C = {:.4f}'.format(*res.x))

# %% [markdown]
# ## Challenge Problem) Improved Model Selection

# %% [markdown]
# In lecture we saw that the AIC could be used as a model selection technique.
#
# As a reminder:
#
# $$\mathrm{AIC} \equiv -2 \ln \mathcal{L} + 2k + \frac{2k(k+1)}{N - k -1},$$
#
# where $N$ is the number of observations, $k$ is the number of model parameters, and models with the smallest AIC are preffered.

# %% [markdown]
# **Challenge 0a**
#
# For the data simulated in the previous problem – calculate the AIC for polynomials of degree 1 through 10.
#
# Plot the AIC as a function of polynomial degree. According to the AIC, which model best replicates the observations?
#
# Do you notice anything interesting about your results?

# %%
# complete
